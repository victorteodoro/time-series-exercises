# %% [markdown]
# # Libraries and data

# %%
# !pip freeze

# %%
# Path to the folder
# %cd /content/drive/MyDrive/Python - Time Series Forecasting/Modern Time Series Forecasting Techniques /CAPSTONE PROJECT: Prophet
# Out:
# /content/drive/MyDrive/Python - Time Series Forecasting/Modern Time Series Forecasting Techniques /CAPSTONE PROJECT: Prophet

# %%
# Import libraries
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
from prophet.diagnostics import cross_validation, performance_metrics

# %%
# Load the CSV file
df = pd.read_csv('DHS_weekly.csv')
# Rename the columns, date to 'ds' and target variable to 'y'
df.rename(columns={'Date': 'ds', 'Total Individuals in Shelter': 'y'}, inplace=True)
# convert the column 'date' to datetime
df['ds'] = pd.to_datetime(df['ds'])
df.tail()
# Out:
#             ds       y  Easter  Thanksgiving  Christmas  Temperature
# 361 2020-12-06  375444       0             0          0    10.072857
# 362 2020-12-13  375820       0             0          0     8.208571
# 363 2020-12-20  375615       0             0          0     3.535714
# 364 2020-12-27  374203       0             0          1     7.510000
# 365 2021-01-03  212514       0             0          0     6.625000

# %%
# Prepare holiday dataframe for Easter
holidays = pd.DataFrame({
    'holiday': 'Easter',  # Name of the holiday
    'ds': df['ds'][df['Easter'] == 1],  # Dates of the holiday
    'lower_window': 0,  # Number of days before the holiday to include in the effect
    'upper_window': 1,  # Number of days after the holiday to include in the effect
})

# Loop through other holidays (Thanksgiving and Christmas) to append them to the holidays dataframe
for holiday in ['Thanksgiving', 'Christmas']:
    temp = pd.DataFrame({
        'holiday': holiday,  # Name of the holiday
        'ds': df['ds'][df[holiday] == 1],  # Dates of the holiday
        'lower_window': 0,  # Number of days before the holiday to include in the effect
        'upper_window': 1,  # Number of days after the holiday to include in the effect
    })
    holidays = pd.concat([holidays, temp])  # Concatenate the new holiday dataframe to the existing holidays dataframe

holidays

# %% [markdown]
# # Prophet Model

# %%
# Assuming the test set is intended to be for the last 60 days in the dataset
max_date = df['ds'].max()  # Get the maximum date in the dataset
split_date = max_date - pd.Timedelta(weeks=13)  # Set the split date 13 weeks (91 days) before the last date

# Split the data into training and testing sets based on the split date
train_df = df[df['ds'] <= split_date]  # Training set includes data up to and including the split date
test_df = df[df['ds'] > split_date]  # Testing set includes data after the split date

# %%
# Initialize the Prophet model
model = Prophet(holidays=holidays) # Add the holidays
model.add_regressor('Temperature')  # Adding temperature as a regressor
# Fit the model on the training data
model.fit(train_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/9vh9xy52.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/4syecnf6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23103', 'data', 'file=/tmp/tmpjyzxepva/9vh9xy52.json', 'init=/tmp/tmpjyzxepva/4syecnf6.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model_zz43osa/prophet_model-20240425150335.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:03:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:03:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Create a dataframe for predictions
future_df = model.make_future_dataframe(periods=13, freq='W')  # Generate future dates for 13 weeks

# Include the regressors in the future dataframe
future_df = future_df.merge(df[['ds', 'Temperature']], on='ds', how='left')

# Predict over the future dataframe
forecast = model.predict(future_df)

# %%
# Evaluate predictions

# Aligning predicted 'yhat' with the actual 'y' in the test set
test_df = test_df.set_index('ds')  # Set the index of test_df to 'ds' (date)
forecast.set_index('ds', inplace=True)  # Set the index of forecast to 'ds' (date)
forecast = forecast.join(test_df['y'])  # Join the actual 'y' values from the test set to the forecast dataframe

# Calculate mean absolute error
forecast['error'] = (forecast['y'] - forecast['yhat']).abs()  # Calculate the absolute error between actual and predicted values
mae = forecast['error'].mean()  # Calculate the mean of the absolute errors
print(f"Mean Absolute Error: {mae}")  # Print the Mean Absolute Error
# Out:
# Mean Absolute Error: 29485.304917293375

# %%
# Visualizing the forecast
from prophet.plot import plot_plotly
plot_plotly(model, forecast.reset_index())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3
31T00:00:00","2014-09-07T00:00:00","2014-09-14T00:00:00","2014-09-21T00:00:00","2014-09-28T00:00:00","2014-10-05T00:00:00","2014-10-12T00:00:00","2014-10-19T00:00:00","2014-10-26T00:00:00","2014-11-02T00:00:00","2014-11-09T00:00:00","2014-11-16T00:00:00","2014-11-23T00:00:00","2014-11-30T00:00:00","2014-12-07T00:00:00","2014-12-14T00:00:00","2014-12-21T00:00:00","2014-12-28T00:00:00","2015-01-04T00:00:00","2015-01-11T00:00:00","2015-01-18T00:00:00","2015-01-25T00:00:00","2015-02-01T00:00:00","2015-02-08T00:00:00","2015-02-15T00:00:00","2015-02-22T00:00:00","2015-03-01T00:00:00","2015-03-08T00:00:00","2015-03-15T00:00:00","2015-03-22T00:00:00","2015-03-29T00:00:00","2015-04-05T00:00:00","2015-04-12T00:00:00","2015-04-19T00:00:00","2015-04-26T00:00:00","2015-05-03T00:00:00","2015-05-10T00:00:00","2015-05-17T00:00:00","2015-05-24T00:00:00","2015-05-31T00:00:00","2015-06-07T00:00:00","2015-06-14T00:00:00","2015-06-21T00:00:00","2015-06-28T00:00:00","2015-07-05T00:00:00","2015-07-12T00:00:00","2015-07-19T00:00:00","2015-07-26T00:00:00","2015-08-02T00:00:00","2015-08-09T00:00:00","2015-08-16T00:00:00","2015-08-23T00:00:00","2015-08-30T00:00:00","2015-09-06T00:00:00","2015-09-13T00:00:00","2015-09-20T00:00:00","2015-09-27T00:00:00","2015-10-04T00:00:00","2015-10-11T00:00:00","2015-10-18T00:00:00","2015-10-25T00:00:00","2015-11-01T00:00:00","2015-11-08T00:00:00","2015-11-15T00:00:00","2015-11-22T00:00:00","2015-11-29T00:00:00","2015-12-06T00:00:00","2015-12-13T00:00:00","2015-12-20T00:00:00","2015-12-27T00:00:00","2016-01-03T00:00:00","2016-01-10T00:00:00","2016-01-17T00:00:00","2016-01-24T00:00:00","2016-01-31T00:00:00","2016-02-07T00:00:00","2016-02-14T00:00:00","2016-02-21T00:00:00","2016-02-28T00:00:00","2016-03-06T00:00:00","2016-03-13T00:00:00","2016-03-20T00:00:00","2016-03-27T00:00:00","2016-04-03T00:00:00","2016-04-10T00:00:00","2016-04-17T00:00:00","2016-04-24T00:00:00","2016-05-01T00:00:00","2016-05-08T00:00:00","2016-05-15T00:00:00","2016-05-22T00:00:00","2016-05-29T00:00:00","2016-06-05T00:00:00","2016-06-12T00:00:00","2016-06-19T00:00:00","2016-06-26T00:00:00","2016-07-03T00:00:00","2016-07-10T00:00:00","2016-07-17T00:00:00","2016-07-24T00:00:00","2016-07-31T00:00:00","2016-08-07T00:00:00","2016-08-14T00:00:00","2016-08-21T00:00:00","2016-08-28T00:00:00","2016-09-04T00:00:00","2016-09-11T00:00:00","2016-09-18T00:00:00","2016-09-25T00:00:00","2016-10-02T00:00:00","2016-10-09T00:00:00","2016-10-16T00:00:00","2016-10-23T00:00:00","2016-10-30T00:00:00","2016-11-06T00:00:00","2016-11-13T00:00:00","2016-11-20T00:00:00","2016-11-27T00:00:00","2016-12-04T00:00: ...

# %% [markdown]
# # PArameter Tuning

# %%
from prophet.diagnostics import cross_validation, performance_metrics
import itertools
import numpy as np

# %%
# Define all combinations of parameters for grid search
param_grid = {
    'changepoint_prior_scale': [0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.1, 1.0, 10.0],
    'holidays_prior_scale': [0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative']
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here

# %%
# Iterate over all parameter combinations
for params in all_params:
    # Initialize and fit the Prophet model with the given parameters and holidays
    m = Prophet(holidays=holidays, **params).fit(train_df)

    # Perform cross-validation
    df_cv = cross_validation(
        m,
        initial='1500 days',  # Initial training period
        period='42 days',     # Period between cutoff dates
        horizon='91 days',    # Forecast horizon
        parallel="processes"  # Use parallel processing
    )

    # Calculate performance metrics
    df_p = performance_metrics(df_cv, rolling_window=1)

    # Append the first RMSE value to the rmses list
    rmses.append(df_p['rmse'].values[0])
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/xbujd62n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51900', 'data', 'file=/tmp/tmpjyzxepva/n624b569.json', 'init=/tmp/tmpjyzxepva/xbujd62n.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelblky345i/prophet_model-20240425152759.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:27:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/36eb8fh1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/9grqv2uw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85503', 'data', 'file=/tmp/tmpjyzxepva/36eb8fh1.json', 'init=/tmp/tmpjyzxepva/9grqv2uw.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model8kl5icbb/prophet_model-20240425152759.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:28:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:28:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/agxqqiv1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/6g_emeab.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48120', 'data', 'file=/tmp/tmpjyzxepva/agxqqiv1.json', 'init=/tmp/tmpjyzxepva/6g_emeab.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modeldvz6tjod/prophet_model-20240425152800.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:28:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:28:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/pbyj9ewu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/c4muzsa9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75277', 'data', 'file=/tmp/tmpjyzxepva/pbyj9ewu.json', 'init=/tmp/tmpjyzxepva/c4muzsa9.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model8e5oxs9l/prophet_model-20240425152801.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:28:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:28:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/64c6118t.json
# 15:28:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/s0r4vq1r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42512', 'data', 'file=/tmp/tmpjyzxepva/64c6118t.json', 'init=/tmp/tmpjyzxepva/s0r4vq1r.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model5k88omka/prophet_model-20240425152801.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:28:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/7rilag17.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/pcm4wq9w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16668', 'data', 'file=/tmp/tmpjyzxepva/7rilag17.json', 'init=/tmp/tmpjyzxepva/pcm4wq9w.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelf0bsoelf/prophet_model-20240425152802.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:28:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:28:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/blrg4y42.json
# 15:28:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/_3c64mpi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80073', 'data', 'file=/tmp/tmpjyzxepva/blrg4y42.json', 'init=/tmp/tmpjyzxepva/_3c64mpi.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model118sk50a/prophet_model-20240425152803.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:28:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/mbsk4rtw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/bcgcurpr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34096', 'data', 'file=/tmp/tmpjyzxepva/mbsk4rtw.json', 'init=/tmp/tmpjyzxepva/bcgcurpr.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelz_d52132/prophet_model-20240425152804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:28:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:28:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/sw3c80dc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/t2nfdc9p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4208', 'data', 'file=/tmp/tmpjyzxepva/sw3c80dc.json', 'init=/tmp/tmpjyzxepva/t2nfdc9p.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelnynqpnnm/prophet_model-20240425152804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:28:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:28:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 15:28:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/loeeyaah.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/oivdzigu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31593', 'data', 'file=/tmp/tmpjyzxepva/loeeyaah.json', 'init=/tmp/tmpjyzxepva/oivdzigu.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_mod
json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6611', 'data', 'file=/tmp/tmpjyzxepva/1uzy9tkk.json', 'init=/tmp/tmpjyzxepva/4hdlfdss.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelh6h_1f23/prophet_model-20240425153301.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 15:33:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/gt1341t1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/i87yuj4o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13537', 'data', 'file=/tmp/tmpjyzxepva/gt1341t1.json', 'init=/tmp/tmpjyzxepva/i87yuj4o.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelhapukn48/prophet_model-20240425153301.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/qbdg1fxr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/slv9f7v2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5712', 'data', 'file=/tmp/tmpjyzxepva/qbdg1fxr.json', 'init=/tmp/tmpjyzxepva/slv9f7v2.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model_5rcz00n/prophet_model-20240425153302.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 15:33:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/gyiu_o50.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/pmr4t1_m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82571', 'data', 'file=/tmp/tmpjyzxepva/gyiu_o50.json', 'init=/tmp/tmpjyzxepva/pmr4t1_m.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modeljuipinwu/prophet_model-20240425153302.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/ggznspjq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/dvm8xrkh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18698', 'data', 'file=/tmp/tmpjyzxepva/ggznspjq.json', 'init=/tmp/tmpjyzxepva/dvm8xrkh.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelhbow7xge/prophet_model-20240425153302.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 15:33:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/eufd3nsj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/5rs1xvom.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7933', 'data', 'file=/tmp/tmpjyzxepva/eufd3nsj.json', 'init=/tmp/tmpjyzxepva/5rs1xvom.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model4_1t1nmf/prophet_model-20240425153303.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/0abtatqi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/14j5c_72.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54571', 'data', 'file=/tmp/tmpjyzxepva/0abtatqi.json', 'init=/tmp/tmpjyzxepva/14j5c_72.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modely9wykm9c/prophet_model-20240425153303.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/mqd9sbxn.json
# 15:33:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/h8dyik3e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31829', 'data', 'file=/tmp/tmpjyzxepva/mqd9sbxn.json', 'init=/tmp/tmpjyzxepva/h8dyik3e.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelnaes3br8/prophet_model-20240425153304.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/iuddi335.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/fh8ok54b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51122', 'data', 'file=/tmp/tmpjyzxepva/iuddi335.json', 'init=/tmp/tmpjyzxepva/fh8ok54b.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelbon4gq7p/prophet_model-20240425153304.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 15:33:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/u18gp_43.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/r2klkqwy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13172', 'data', 'file=/tmp/tmpjyzxepva/u18gp_43.json', 'init=/tmp/tmpjyzxepva/r2klkqwy.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelq634nlaq/prophet_model-20240425153305.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/ecj951be.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/s0dccozj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44823', 'data', 'file=/tmp/tmpjyzxepva/ecj951be.json', 'init=/tmp/tmpjyzxepva/s0dccozj.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_modelgy6cnio1/prophet_model-20240425153305.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/qjn2kw8l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/ocmggcc0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27608', 'data', 'file=/tmp/tmpjyzxepva/qjn2kw8l.json', 'init=/tmp/tmpjyzxepva/ocmggcc0.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model62yr4nyj/prophet_model-20240425153306.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/gcivqb1m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/d67qmofp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39587', 'data', 'file=/tmp/tmpjyzxepva/gcivqb1m.json', 'init=/tmp/tmpjyzxepva/d67qmofp.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model7hwqpp4s/prophet_model-20240425153306.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/ao236jmx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjyzxepva/0n6vlzt1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41522', 'data', 'file=/tmp/tmpjyzxepva/ao236jmx.json', 'init=/tmp/tmpjyzxepva/0n6vlzt1.json', 'output', 'file=/tmp/tmpjyzxepva/prophet_model8141x0l8/prophet_model-20240425153307.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:33:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:33:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 15:33:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Find the best parameters

# Get the row of the minimum RMSE value in the rmses list
best_params = all_params[np.argmin(rmses)]
print('Best Parameters:', best_params)
# Out:
# Best Parameters: {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 10.0, 'holidays_prior_scale': 10.0, 'seasonality_mode': 'multiplicative'}
